# %% [markdown]
# <a href="https://colab.research.google.com/github/hadziqqbadii/KKA-X-Semester-1/blob/main/3_Aplikasi_Sederhana_Kalkulator_Hadziq_HB_X_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
jari_jari = int(input("Masukkan jari jari tabung dengan panjang (cm):  "))
tinggi = int(input("Masukkan tinggi tabung dengan panjang (cm):  "))

volume = 22/7 * 15 * 15 * 28

print(f"\nVolume dari tabung tersebut yaitu {volume} cm^3")
# Out:
# Masukkan jari jari tabung dengan panjang (cm):  15
# Masukkan tinggi tabung dengan panjang (cm):  28
#
# Volume dari tabung tersebut yaitu 19800.0 cm^3
