# %% [markdown]
# <a href="https://colab.research.google.com/github/hadziqqbadii/KKA-X-Semester-1/blob/main/1_Fungsi_Print_Hadziq_X_6_2025.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Nama : Hadziq Husnul Badii

# %% [markdown]
# Kelas : X.6

# %% [markdown]
# Absen : 13

# %%
print("Halo dunia!")
# Out:
# Halo dunia!

# %%
print("""
Nama : Hadziq
Kelas : X.6
""")
# Out:
# Nama : Hadziq
# Kelas : X.6

# %%
nama = "hadziq husnul badii"
usia = 14

print(nama)
print(usia)
# Out:
# hadziq husnul badii
# 14

# %%
warna_favorit = "hijau"
berat_badan = 43

print(warna_favorit)
print(berat_badan)
# Out:
# hijau
# 43

# %% [markdown]
# #Menampilkan Teks Bebas dan Nilai Variabel

# %%
nama = "hadziq husnul badii"
berat_badan = 43

# %%
print("nama: " + nama)
# Out:
# nama: hadziq husnul badii

# %%
print("berat badan: " + str(berat_badan))
# Out:
# berat badan: 43

# %%
print("nama:", nama ,"loh")
# Out:
# nama: hadziq husnul badii loh

# %%
print("berat badan:" , berat_badan)
# Out:
# berat badan: 43

# %%
print(f"nama:  {nama} loh")
# Out:
# nama:  hadziq husnul badii loh

# %% [markdown]
# #Escape Character

# %%
print("""Nama: Hadziq Husnul Badii
Kelas: X.6
No. Absen: 13""")
# Out:
# Nama: Hadziq Husnul Badii
# Kelas: X.6
# No. Absen: 13

# %%
print("Nama: Hadziq Husnul Badii")
print("Kelas: X.6")
print("No. Absen: 13")
# Out:
# Nama: Hadziq Husnul Badii
# Kelas: X.6
# No. Absen: 13

# %%
print("Nama: Hadziq  Absen: 13")
# Out:
# Nama: Hadziq  Absen: 13

# %%
print("Nama\t\t: Hadziq Husnul Badii\nKelas\t\t: X.6\nNo. Absen\t: 13")
# Out:
# Nama		: Hadziq Husnul Badii
# Kelas		: X.6
# No. Absen	: 13

# %%
print('Nama\t\t: Hadziq Husnul Badii\nKelas\t\t: X.6\nNo. Absen\t: 13')
# Out:
# Nama		: Hadziq Husnul Badii
# Kelas		: X.6
# No. Absen	: 13

# %%
print('Nama\t\t: Ja\'far Shodiq\nKelas\t\t: X.6\nNo. Absen\t: 29')
# Out:
# Nama		: Ja'far Shodiq
# Kelas		: X.6
# No. Absen	: 29

# %%
print(f"nama:  {nama} loh")
# Out:
# Lokasi file tugas KKA: C:\Tugas Hadziq

# %%
print("Nama\t\t: Ja'far Shodiq\nKelas\t\t: X.6\nNo. Absen\t: 29")
# Out:
# Nama		: Ja'far Shodiq
# Kelas		: X.6
# No. Absen	: 29

# %%
print("Bu Shinta berkata, \"Tolong perhatikan ke layar TV!\".")
# Out:
# Bu Shinta berkata, "Tolong perhatikan ke layar TV!".

# %%
print('Bu Shinta berkata, "Tolong perhatikan ke layar TV!".')
# Out:
# Bu Shinta berkata, "Tolong perhatikan ke layar TV!".

# %% [markdown]
# #Parameter Fungsi Print

# %%
tahun=2000
bulan="Februari"
tanggal=18

print(tahun, end="-")
print(bulan, end="-")
print(tanggal)
# Out:
# 2000-Februari-18

# %%
print(tanggal, end="/")
print(bulan, end="/")
print(tahun)
# Out:
# 18/Februari/2000

# %%
nama_siswa_1 = "Fida"
nama_siswa_2 = "Aji"
nama_siswa_3 = "Hadziq"

print(nama_siswa_2, end="~")
print(nama_siswa_3, end="~")
print(nama_siswa_1)
# Out:
# Aji~Hadziq~Fida

# %%
print(nama_siswa_2, nama_siswa_1, nama_siswa_3, nama_siswa_2, sep="-")
# Out:
# Aji-Fida-Hadziq-Aji
